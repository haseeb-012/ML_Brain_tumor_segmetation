# %% [markdown]
# <a href="https://colab.research.google.com/github/haseeb-012/ML_Brain_tumor_segmetation/blob/main/Brain_Tumor_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introduction: Advancing Brain Tumor Segmentation with the Power of YOLOv11 and SAM2
#
# Accurate brain tumor segmentation from MRI is crucial for diagnosis. This work explores integrating YOLOv11 and SAM2 for enhanced segmentation, aiming to improve accuracy, speed, and consistency for better clinical decisions.

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 31.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 68.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Train the model
train_results = model.train(
    data="/content/BTD_SEGMENTATION.v2i.yolov11/BTD_SEGMENTATION.v2i.yolov11/data.yaml",  # path to dataset YAML
    epochs=20,  # number of training epochs
    imgsz=640,  # training image size
    device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 88.1MB/s]
# Ultralytics 8.3.160 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO11n model

# Run batched inference on a list of images
results = model("/content/YOLO11-and-SAM2-main/YOLO11-and-SAM2-main/test_images/pituitary_5.jpg")  # return a list of Results objects
results[0].show()

# Process results list
for result in results:
    boxes = result.boxes  # Boxes object for bounding box outputs
    print(boxes)
# Out:
# image 1/1 /content/YOLO11-and-SAM2-main/YOLO11-and-SAM2-main/test_images/pituitary_5.jpg: 640x640 1 pituitary, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=640x640>
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2.], device='cuda:0')
# conf: tensor([0.7034], device='cuda:0')
# data: tensor([[274.4222, 219.7255, 348.0877, 276.5162,   0.7034,   2.0000]], device='cuda:0')
# id: None
# is_track: False
# orig_shape: (640, 640)
# shape: torch.Size([1, 6])
# xywh: tensor([[311.2549, 248.1208,  73.6655,  56.7907]], device='cuda:0')
# xywhn: tensor([[0.4863, 0.3877, 0.1151, 0.0887]], device='cuda:0')
# xyxy: tensor([[274.4222, 219.7255, 348.0877, 276.5162]], device='cuda:0')
# xyxyn: tensor([[0.4288, 0.3433, 0.5439, 0.4321]], device='cuda:0')

# %%
from ultralytics import YOLO
from ultralytics import SAM

# Load the YOLO model
yolo_model = YOLO("/content/runs/detect/train/weights/best.pt")  # pretrained YOLO model

# Run batched inference on a list of images
results = yolo_model("/content/YOLO11-and-SAM2-main/YOLO11-and-SAM2-main/test_images/")  # return a list of Results objects

# Load the SAM model
sam_model = SAM("sam2_b.pt")

for result in results:
     class_ids = result.boxes.cls.int().tolist()  # noqa
     if len(class_ids):
         boxes = result.boxes.xyxy  # Boxes object for bbox outputs
         sam_results = sam_model(result.orig_img, bboxes=boxes, verbose=False, save=True, device=0)
# Out:
# image 1/3 /content/YOLO11-and-SAM2-main/YOLO11-and-SAM2-main/test_images/glioma_2.jpg: 640x640 (no detections), 8.6ms
# image 2/3 /content/YOLO11-and-SAM2-main/YOLO11-and-SAM2-main/test_images/no_tumor_1.jpg: 640x640 1 no_tumor, 9.5ms
# image 3/3 /content/YOLO11-and-SAM2-main/YOLO11-and-SAM2-main/test_images/pituitary_5.jpg: 640x640 1 pituitary, 10.5ms
# Speed: 2.0ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict4
# Results saved to runs/segment/predict4

# %% [markdown]
# ## Conclusion
#
# This project explored the integration of YOLOv11 and SAM2 for enhancing brain tumor segmentation from MRI images. We successfully installed the necessary libraries, trained a YOLOv11 model on a custom dataset for brain tumor detection, achieving  of 0.652 on the validation set. Subsequently, we demonstrated the combined approach by using the trained YOLOv11 model to provide bounding box prompts to the SAM2 model, generating segmentation masks for brain tumors in test images. The results indicate that this integrated approach holds promise for accurate and efficient brain tumor segmentation, laying the groundwork for further advancements in this critical medical imaging task.
